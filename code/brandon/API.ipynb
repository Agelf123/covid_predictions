# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import time
import requests

# %%
url = "https://ncdp.columbia.edu/library/mapsmapping-projects/us-natural-hazards-index/"
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
soup.extract()
# Out:
# <!DOCTYPE html>
# <!--[if IE 6]>
# <html id="ie6" lang="en-US">
# <![endif]--><!--[if IE 7]>
# <html id="ie7" lang="en-US">
# <![endif]--><!--[if IE 8]>
# <html id="ie8" lang="en-US">
# <![endif]--><!--[if !(IE 6) | !(IE 7) | !(IE 8)  ]><!--><html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://fonts.googleapis.com/css?family=Abel" rel="stylesheet" type="text/css"/>
# <link href="https://ncdp.columbia.edu/xmlrpc.php" rel="pingback"/>
# <link href="https://ncdp.columbia.edu/custom-content/themes/ncdp/favicon.ico" rel="shortcut icon"/>
# <!--[if lt IE 9]>
# <script src="https://ncdp.columbia.edu/custom-content/themes/twentyeleven/js/html5.js" type="text/javascript"></script>
# <![endif]-->
# <!-- This site is optimized with the Yoast SEO plugin v14.0.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>US Natural Hazards Index - National Center for Disaster Preparedness | NCDP</title>
# ...

# %%
table = soup.find_all('html', {'class': 'esriLtr jimu-ltr en-us en dj_webkit dj_chrome dj_contentbox has-webkit has-no-quirks'})

# %%
table
# Out:
# []
