# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv('~/downloads/full.csv')
# Out:
# /Users/brandongreenspan/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (351) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.sort_values(by = 'hazard score', ascending= False)
# Out:
#       Unnamed: 0  Unnamed: 0_x            county_x state  hazard score  \
# 175          175           175  los angeles county    CA            19
# 382          382           382      chatham county    GA            18
# 1131        1131          1131   tangipahoa parish    LA            18
# 48            48            48       mobile county    AL            18
# 306          306           306     escambia county    FL            17
# ...          ...           ...                 ...   ...           ...
# 1322        1322          1322     mahnomen county    MN             6
# 1324        1324          1324       martin county    MN             6
# 2972        2972          2972         door county    WI             6
# 1326        1326          1326       meeker county    MN             6
# 646          646           646        lewis county    ID             5
#
#       wildfire  tornado  landslide  hurricane  earthquake  ...  \
# ...

# %%
df[df.columns].dtypes.value_counts()
# Out:
# float64    743
# int64      110
# object       5
# dtype: int64

# %%
df['wildfire'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['tornado'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['landslide'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['hurricane'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['earthquake'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['drought'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['heatwave'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['avalanche'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['flood'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)

# %%
df['hazard score'] = df['wildfire'] + df['tornado'] + df['landslide'] + df['hurricane'] + df['earthquake'] + df['drought'] + df['heatwave'] + df['avalanche'] + df['flood']

# %%
df['hazard score']
# Out:
# 0       12
# 1       17
# 2        9
# 3       13
# 4       12
#         ..
# 3103    10
# 3104    13
# 3105    11
# 3106     9
# 3107     7
# Name: hazard score, Length: 3108, dtype: int64

# %%
df[df.columns[4:11]]
# Out:
#       hazard score  wildfire  tornado  landslide  hurricane  earthquake  \
# 0               12         2        2          1          2           1
# 1               17         3        3          1          3           1
# 2                9         2        1          1          2           1
# 3               13         2        2          2          1           2
# 4               12         1        3          3          1           1
# ...            ...       ...      ...        ...        ...         ...
# 3103            10         1        1          2          0           2
# 3104            13         2        1          2          0           2
# 3105            11         2        1          2          0           2
# 3106             9         2        1          1          0           2
# 3107             7         1        1          2          0           1
#
#       drought
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...

# %%
df.to_csv('./updated_hazard_scores.csv')

# %%
df['total inpatient, beds set up_y'].value_counts()
# Out:
# 0.0    3108
# Name: total inpatient, beds set up_y, dtype: int64
