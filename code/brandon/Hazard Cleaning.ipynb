# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv('~/downloads/combined.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          county state  hazard score wildfire volcano tornado  \
# 0           0  autauga county    AL            13   Medium    None  Medium
# 1           1  baldwin county    AL            18     High    None    High
# 2           2  barbour county    AL            10   Medium    None     Low
# 3           3     bibb county    AL            14   Medium    None  Medium
# 4           4   blount county    AL            13      Low    None    High
#
#   snowfall landslide hurricane  ... nurse practitioners w/npi_y  \
# 0      Low       Low    Medium  ...                         NaN
# 1      Low       Low      High  ...                         NaN
# 2      Low       Low    Medium  ...                         NaN
# 3      Low    Medium       Low  ...                         NaN
# 4      Low      High       Low  ...                         NaN
#
#   skilled nurs care, beds set up_y nurse practitioners, fmle w/npi_y  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#   clin nurs specialist,male w/npi # nursing facilities  \
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
#
#    cert nurse midwvs,ft oth emptyp_y nursing facilities total beds  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    nurse practitioners_y  advpractnurs midwve,male w/npi  st_num
# 0                    NaN                             NaN     NaN
# 1                    NaN                             NaN     NaN
# 2                    NaN                             NaN     NaN
# 3                    NaN                             NaN     NaN
# 4                    NaN                             NaN     NaN
#
# [5 rows x 856 columns]

# %%
df[df.columns[4:13]]
# Out:
#      wildfire volcano tornado snowfall landslide hurricane earthquake drought  \
# 0      Medium    None  Medium      Low       Low    Medium        Low    None
# 1        High    None    High      Low       Low      High        Low    None
# 2      Medium    None     Low      Low       Low    Medium        Low    None
# 3      Medium    None  Medium      Low    Medium       Low     Medium    None
# 4         Low    None    High      Low      High       Low        Low    None
# ...       ...     ...     ...      ...       ...       ...        ...     ...
# 3103      Low    None     Low   Medium    Medium      None     Medium    None
# 3104   Medium  Medium     Low     High    Medium      None     Medium    None
# 3105   Medium    None     Low     High    Medium      None     Medium    None
# 3106   Medium    None     Low   Medium       Low      None     Medium    None
# 3107      Low    None     Low   Medium    Medium      None        Low    None
#
#      heatwave
# 0         Low
# 1        High
# 2         Low
# 3        High
# 4      Medium
# ...       ...
# 3103     High
# 3104      Low
# 3105     High
# 3106      Low
# 3107      Low
#
# [3108 rows x 9 columns]

# %%
df.drop(columns= ['volcano', 'snowfall'], inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0          county state  hazard score wildfire tornado landslide  \
# 0           0  autauga county    AL            13   Medium  Medium       Low
# 1           1  baldwin county    AL            18     High    High       Low
# 2           2  barbour county    AL            10   Medium     Low       Low
# 3           3     bibb county    AL            14   Medium  Medium    Medium
# 4           4   blount county    AL            13      Low    High      High
#
#   hurricane earthquake drought  ... nurse practitioners w/npi_y  \
# 0    Medium        Low    None  ...                         NaN
# 1      High        Low    None  ...                         NaN
# 2    Medium        Low    None  ...                         NaN
# 3       Low     Medium    None  ...                         NaN
# 4       Low        Low    None  ...                         NaN
#
#   skilled nurs care, beds set up_y nurse practitioners, fmle w/npi_y  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#    clin nurs specialist,male w/npi # nursing facilities  \
# 0                              NaN                  NaN
# 1                              NaN                  NaN
# 2                              NaN                  NaN
# 3                              NaN                  NaN
# 4                              NaN                  NaN
#
#    cert nurse midwvs,ft oth emptyp_y  nursing facilities total beds  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#    nurse practitioners_y  advpractnurs midwve,male w/npi  st_num
# 0                    NaN                             NaN     NaN
# 1                    NaN                             NaN     NaN
# 2                    NaN                             NaN     NaN
# 3                    NaN                             NaN     NaN
# 4                    NaN                             NaN     NaN
#
# [5 rows x 854 columns]

# %%
df['wildfire'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['tornado'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['landslide'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['hurricane'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['earthquake'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['drought'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['heatwave'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['avalanche'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)
df['flood'].replace({
    'None' : 0,
    'Low' : 1,
    'low' : 1,
    'Medium': 2,
    'High' : 3
}, inplace = True)

# %%
df['hazard score'] = df['wildfire'] + df['tornado'] + df['landslide'] + df['hurricane'] + df['earthquake'] + df['drought'] + df['heatwave'] + df['avalanche'] + df['flood']

# %%
df['hazard score']
# Out:
# 0       12
# 1       17
# 2        9
# 3       13
# 4       12
#         ..
# 3103    10
# 3104    13
# 3105    11
# 3106     9
# 3107     7
# Name: hazard score, Length: 3108, dtype: int64

# %%
df
# Out:
#       Unnamed: 0             county state  hazard score  wildfire  tornado  \
# 0              0     autauga county    AL            12         2        2
# 1              1     baldwin county    AL            17         3        3
# 2              2     barbour county    AL             9         2        1
# 3              3        bibb county    AL            13         2        2
# 4              4      blount county    AL            12         1        3
# ...          ...                ...   ...           ...       ...      ...
# 3103        3103  sweetwater county    WY            10         1        1
# 3104        3104       teton county    WY            13         2        1
# 3105        3105       uinta county    WY            11         2        1
# 3106        3106    washakie county    WY             9         2        1
# 3107        3107      weston county    WY             7         1        1
#
#       landslide  hurricane  earthquake  drought  ...  \
# 0             1          2           1        0  ...
# 1             1          3           1        0  ...
# 2             1          2           1        0  ...
# 3             2          1           2        0  ...
# 4             3          1           1        0  ...
# ...         ...        ...         ...      ...  ...
# 3103          2          0           2        0  ...
# 3104          2          0           2        0  ...
# 3105          2          0           2        0  ...
# 3106          1          0           2        0  ...
# 3107          2          0           1        0  ...
#
#       nurse practitioners w/npi_y  skilled nurs care, beds set up_y  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 3103                          NaN                               NaN
# 3104                          NaN                               NaN
# 3105                          NaN                               NaN
# 3106                          NaN                               NaN
# 3107                          NaN                               NaN
#
#       nurse practitioners, fmle w/npi_y  clin nurs specialist,male w/npi  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
# ...                                 ...                              ...
# 3103                                NaN                              NaN
# 3104                                NaN                              NaN
# 3105                                NaN                              NaN
# 3106                                NaN                              NaN
# 3107                                NaN                              NaN
#
#      # nursing facilities  cert nurse midwvs,ft oth emptyp_y  \
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
# ...                   ...                                ...
# 3103                  NaN                                NaN
# 3104                  NaN                                NaN
# 3105                  NaN                                NaN
# 3106                  NaN                                NaN
# 3107                  NaN                                NaN
#
#       nursing facilities total beds  nurse practitioners_y  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 3103                            NaN                    NaN
# 3104                            NaN                    NaN
# 3105                            NaN                    NaN
# 3106                            NaN                    NaN
# 3107                            NaN                    NaN
#
#       advpractnurs midwve,male w/npi  st_num
# 0                                NaN     NaN
# 1                                NaN     NaN
# 2                                NaN     NaN
# 3                                NaN     NaN
# 4                                NaN     NaN
# ...                              ...     ...
# 3103                             NaN     NaN
# 3104                             NaN     NaN
# 3105                             NaN     NaN
# 3106                             NaN     NaN
# 3107                             NaN     NaN
#
# [3108 rows x 854 columns]

# %%
df.to_csv('./updated_hazard_scores.csv')
