# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
merge = pd.read_csv('merged_census_and_hazards_df.csv')
hazzard = pd.read_csv('hazard_risks.csv')

# %%
merge[merge['county'].str.contains('City')]
# Out:
#       Unnamed: 0                 county state  hazard score  wildfire  \
# 699          699    Roanoke City County    VA            14         1
# 712          712   Richmond City County    VA            14         1
# 1734        1734      James City County    VA            11         1
# 2138        2138   Franklin City County    VA            11         1
# 2219        2219    Fairfax City County    VA            11         1
# 2663        2663    Charles City County    VA            11         1
# 2705        2705     Carson City County    NV            16         3
# 2944        2944    Bedford City County    VA            14         1
# 2989        2989  Baltimore City County    MD            11         1
#
#       tornado  landslide  hurricane  earthquake  drought  ...  \
# 699         1          3          3           1        0  ...
# 712         3          2          3           1        0  ...
# 1734        1          1          3           1        0  ...
# ...

# %%
merge.shape
# Out:
# (3109, 105)

# %%
merge.i
# Out:
# Unnamed: 0                                                                                        0
# county                                                                                            0
# state                                                                                             0
# hazard score                                                                                      0
# wildfire                                                                                          0
#                                                                                                  ..
# Estimate!!SEX AND AGE!!Total population!!18 years and over!!Female                               53
# Estimate!!SEX AND AGE!!Total population!!18 years and over!!Sex ratio (males per 100 females)    53
# Estimate!!SEX AND AGE!!Total population!!65 years and over.1                                     53
# ...
